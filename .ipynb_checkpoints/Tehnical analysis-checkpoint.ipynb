# %% [markdown]
# # Анализ биржевых данных

# %% [markdown]
# ## Cодержание
#
# 1. [Функции](#Функции)
# 2. [Демонстрация работы](#Демонстрация-работы)
#  1. [Загрузка данных](#Загрузка-данных)
#  2. [Стратегия Боллинджера](#Стратегия-Боллинджера)
#  3. [Стратегия пересечения скользящих средних](#Стратегия-пересечения-скользящих-средних)
# 3. [Пары компаний](#Пары-компаний)
#  1. [Koninklijke Philips NV и LGC Capital Ltd](#Koninklijke-Philips-NV-и-LGC-Capital-Ltd)
#  2. [Tesla и ExxonMobil](#Tesla-и-ExxonMobil)

# %% [markdown]
# ## Функции

# %% [markdown]
# Для работы нам понадобятся следующие библотеки

# %%
import requests
import json
import time
import copy
import datetime
import pandas as pd
import numpy as np
import random as rnd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num,num2date, DayLocator, DateFormatter
from mpl_finance import candlestick_ohlc,candlestick2_ohlc
pd.options.display.max_rows = 10
# %config InlineBackend.figure_format = 'svg'
API_KEY = "MQ6BIXLQCTZ9I3DV"

# %% [markdown]
# `prices_from_json_response(apikey,symbol,function,outputsize):`
#
#     Make DataFrame of prices of current company stock from json alphavantage response.
#
#     Args:
#         apikey: Your API key.
#         symbol: The name of the company for your choice.
#         function: The time series of your choice.
#         outputsize: The output parametr for size.
#
#     Returns:
#         prices: DataFrame of prices

# %%
def prices_from_json_response(apikey,symbol,function,outputsize):
    API_URL = "https://www.alphavantage.co/query"
    data = {
        "function": function,
        "symbol": symbol,
        "outputsize": outputsize,
        "datatype": "JSON",
        "apikey": apikey
        }
    json_data=requests.get(API_URL, data).json()['Time Series (Daily)']
    prices=pd.DataFrame(json_data).transpose()
    prices.index.names = ['Date']
    prices.index=pd.to_datetime(prices.index, format='%Y-%m-%d')
    if function=='TIME_SERIES_DAILY':
        prices=prices.rename(columns={"1. open" : "open", "2. high":"high", "3. low":"low", "4. close":"close", "5. volume":"volume"})
    if function=='TIME_SERIES_DAILY_ADJUSTED':
        prices=prices.rename(columns={"1. open" : "open", "2. high":"high", "3. low":"low", "4. close":"close", "5. adjusted close":"adjusted_close","6. volume":"volume","7. dividend amount":"dividend_amount","8. split coefficient":"split_coefficient"})
    prices=prices.astype(float)
    prices = prices.sort_index(axis=0 ,ascending=True)
    return prices

# %% [markdown]
# `prices_from_csv_response(apikey,symbol,function,outputsize):`
#
#     Make DataFrame of prices of current company stock from csv alphavantage response.
#
#     Args:
#         apikey: Your API key.
#         symbol: The name of the company for your choice.
#         function: The time series of your choice.
#         outputsize: The output parametr for size.
#
#     Returns:
#         prices: DataFrame of prices

# %%
def prices_from_csv_response(apikey,symbol,function,outputsize):
    base_url = 'https://www.alphavantage.co/query?'
    request_url = base_url + '&'.join\
        (['function=' + function,
          'outputsize=' + outputsize,
          'datatype=' + 'csv',
          'symbol=' + symbol,
          'apikey=' + apikey])
    data = pd.read_csv(request_url, index_col='timestamp', parse_dates=True)    
    data=data.iloc[::-1]
    data.index.names = ['Date']
    return data

# %% [markdown]
# `prices_from_alphavantage_response(apikey,symbol,datatype,function,outputsize):`
#
#     Make DataFrame of prices of current company stock from alphavantage response.
#
#     Args:
#         apikey: Your API key.
#         symbol: The name of the company for your choice.
#         datatype: type of alphavanttage response
#         function: The time series of your choice.
#         outputsize: The output parametr for size.
#
#     Returns:
#         prices: DataFrame of prices

# %%
def prices_from_alphavantage_response(
        apikey, symbol,
        datatype="csv",
        function='TIME_SERIES_DAILY_ADJUSTED',
        outputsize='compact'):
        time.sleep(15)
        if datatype=="JSON" or datatype=="json":
            return prices_from_json_response(apikey,symbol,function,outputsize)
        elif datatype=="CSV" or datatype=="csv":
            return prices_from_csv_response(apikey,symbol,function,outputsize)
        else:
            print("Not supported format")

# %% [markdown]
# `readydf(df,startdate):`
#
#     Create DataFrame without data before start date.
#
#     Args:
#         df: DataFrame of prices.
#         start date: Date of oldest possible record from new DataFrame
#
#     Returns:
#         Smalldf: New DataFrame

# %%
def readydf(df,startdate):
    Smalldf=df[df.index>=startdate]
    return Smalldf

# %% [markdown]
# `getbollinger(prices,window,safety):`
#
#     Prepare DataFrame for Bollinger strategy usage
#
#     Args:
#         prices: DataFrame of prices
#         window: window for SMA
#         safety: width of bollinger's tube
#
#     Returns:
#         bollingerprices: Ready DataFrame

# %%
def getbollinger(prices,window=3,safety=1):
    bollingerprices=prices
    bollingerprices["adjusted_close_rolling"]=prices["adjusted_close"].rolling(window).mean()
    tmp=safety*prices["adjusted_close"].rolling(window).std()
    bollingerprices["adjusted_close_top"]=bollingerprices["adjusted_close_rolling"]+tmp
    bollingerprices["adjusted_close_bottom"]=bollingerprices["adjusted_close_rolling"]-tmp
    #first_date=bollingerprices.first_valid_index()
    #first_clean_date=first_date+pd.DateOffset(days=window)
    bollingerprices=bollingerprices.iloc[window:]
    return bollingerprices

# %% [markdown]
# `getcrossover(prices,small_window,big_window):`
#
#     Prepare DataFrame for crossover strategy usage
#
#     Args:
#         prices: DataFrame of prices
#         small_window: window for fast SMA
#         big_window: window for slow SMA
#
#     Returns:
#         crossoverprices: Ready DataFrame

# %%
def getcrossover(prices,small_window=3,big_window=30):
    if (big_window<small_window):
        print("Wrong window settings")
        return
    crossoverprices=prices
    crossoverprices["Fast_close_rolling"]=crossoverprices["adjusted_close"].rolling(small_window).mean()
    crossoverprices["Slow_close_rolling"]=crossoverprices["adjusted_close"].rolling(big_window).mean()
    crossoverprices=crossoverprices.iloc[big_window:]
    return crossoverprices

# %% [markdown]
# `drawcandlestick(df):`
#
#     Draw plot of japanese candles
#
#     Args:
#         df: DataFrame of prices
#
#     Returns:
#         Plot of japanese candles

# %%
def drawcandlestick(df):
    fig, ax = plt.subplots(figsize=(7, 7))
    candlestick2_ohlc(ax,df['open'],df['high'],df['low'],df['close'],width=0.5) 
    ax.xaxis.set_major_locator(ticker.MaxNLocator(10))
    xdate = df.index.date
    def mydate(x,pos):
        try:
            return xdate[int(x)]
        except IndexError:
            return ''
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(mydate))
    fig.autofmt_xdate()
    fig.tight_layout()
    plt.show()

# %% [markdown]
# `drawcandlestick2(df):`
#
#     Draw plot of japanese candles with volume bar chart
#
#     Args:
#         df: DataFrame of prices
#
#     Returns:
#         Plot of japanese candles with volume bar chart

# %%
def drawcandlestick2(df):
    candlesticks = zip(date2num(df.index.date),df['open'],df['high'],df['low'],df['close'],df['volume'])
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(1,1,1)
    ax.set_ylabel('Candles', size=20)
    candlestick_ohlc(ax, candlesticks,width=0.5,colorup="black",colordown="red")
    pad = 0.25
    yl = ax.get_ylim()
    ax.set_ylim(yl[0]-(yl[1]-yl[0])*pad,yl[1])
    ax2 = ax.twinx()
    #ax2.set_position(matplotlib.transforms.Bbox([[0.125,0.1],[0.9,0.52]]))
    dates = np.asarray(df.index.date)
    volume = np.asarray(df["volume"])
    pos = df['open']-df['close']<0
    neg = df['open']-df['close']>0
    ax2.bar(dates[pos],volume[pos],color='black',width=1,align='center')
    ax2.bar(dates[neg],volume[neg],color='red',width=1,align='center')
    ax2.set_xlim(min(dates),max(dates))
    yticks = ax2.get_yticks()
    ax2.set_yticks(yticks[::3])
    ax2.yaxis.set_label_position("right")
    ax2.set_ylabel('Volume', size=20)
    xt = ax.get_xticks()
    new_xticks = [datetime.date.isoformat(num2date(d)) for d in xt]
    ax.set_xticklabels(new_xticks,rotation=45, horizontalalignment='right')
    yl = ax2.get_ylim()
    ax2.set_ylim(yl[0],8*yl[1])
    plt.ion()
    plt.show()

# %% [markdown]
# `drawbollinger(bollingerprices):`
#
#     Draw plot of bollinger's tube
#
#     Args:
#         bollingerprices: DataFrame of prices
#
#     Returns:
#         Plot of bollinger's tube

# %%
def drawbollinger(bollingerprices):
    color='#0066FF'
    fig,ax = plt.subplots(figsize=(8, 8))
    ax.set_title('Price and Bollinger Bands')
    ax.set_xlabel('Date')
    l1=ax.plot(bollingerprices.index, bollingerprices["adjusted_close_rolling"],label="Adjusted close rolling", color=color)
    l2=ax.plot(bollingerprices.index, bollingerprices["adjusted_close"],
            color="black",label="Adjusted close", linewidth=1, alpha=1)
    l3=ax.plot(
            bollingerprices.index,  
            bollingerprices["adjusted_close_bottom"],
            label="Tube borders",
            color=color, linewidth=1, alpha=0.4)
    ax.plot(
            bollingerprices.index,  
            bollingerprices["adjusted_close_top"],
            label="Tube borders",
            color=color, linewidth=1, alpha=0.4)
    ax.legend((l2[0].get_label(),l1[0].get_label(),l3[0].get_label()),
        loc='upper center', shadow=False, fontsize='x-large')
    ax.fill_between(
            bollingerprices.index,  
            bollingerprices["adjusted_close_bottom"],
            bollingerprices["adjusted_close_top"],
            color=color, alpha=0.1)
    ax.xaxis.set_major_locator(ticker.MaxNLocator(10))
    myFmt = mdates.DateFormatter('%Y-%m-%d')
    ax.xaxis.set_major_formatter(myFmt)
    fig.autofmt_xdate()
    #fig.tight_layout()

# %% [markdown]
# `drawcrossover(prices):`
#
#     Draw plot of price, slow SMA and fast SMA
#
#     Args:
#         prices: DataFrame of prices
#
#     Returns:
#         Plot of price, slow SMA and fast SMA

# %%
def drawcrossover(prices):
    fig,ax = plt.subplots(figsize=(12, 8))
    ax.set_title('Price and vmoving averages')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price_and_moving_averages')
    ax.plot(prices.index, prices["adjusted_close"],label="Adjusted close", color="red")
    ax.plot(prices.index, prices["Fast_close_rolling"],label="Fast close rolling", color="gray")
    ax.plot(prices.index, prices["Slow_close_rolling"],label="Slow close rolling", color="black")
    ax.legend(loc='upper center', shadow=False, fontsize='x-large')
    ax.xaxis.set_major_locator(ticker.MaxNLocator(10))
    myFmt = mdates.DateFormatter('%Y-%m-%d')
    ax.xaxis.set_major_formatter(myFmt)
    fig.autofmt_xdate()

# %% [markdown]
# `class result_of_trading:`
#
#     Data structure for storing transactions list and current actives for trading strategy
#
#     Attributes:
#         amount:Amount of stocks
#         profit:Profit in $
#         percentage_profit: Profit in percents
#         transactions: DataFrame of transactions
#
#
#     str:
#
#         Overloading  str metod for format output
#
#         Returns:
#             Formatted string
#
#     sell:
#
#         Perform selling transaction
#
#         Args:
#             prices: prices list
#             i: current row of prices list
#
#         Returns:
#
#     buy:
#
#         Perform buying transaction
#
#         Args:
#             prices: prices list
#             i: current row of prices list
#
#         Returns:

# %%
class result_of_trading:
    cash=0
    amount=0
    profit=0
    percentage_profit=0
    transactions = pd.DataFrame(columns=["buy/sell","date","price","amount"])
    def __str__(self):
        s="Profit="+str("%.2f" % self.profit)+"$"+"\n"
        s=s+"Percentage profit="+str("%.2f" %self.percentage_profit)+"%"+"\n"
        s=s+"Amount="+str(self.amount)+"\n"
        s=s+"Cash="+str("%.2f" % self.cash)+"$"+"\n"
        s=s+str(self.transactions)+"\n"
        return s
    def sell(self,prices,i):
        if (self.amount>0):
            selling_amount=rnd.randint(round(0.7*self.amount),self.amount)
            if(selling_amount>0):
                tmp=prices.loc[i,"close"]
                self.cash=self.cash+tmp*selling_amount
                self.amount=self.amount-selling_amount
                transaction=pd.DataFrame([["sell",i,tmp,selling_amount]],columns=["buy/sell","date","price","amount"])
                self.transactions= pd.concat([self.transactions,transaction],ignore_index=True)
    def buy(self,prices,i):
        tmp=prices.loc[i,"close"]
        max_amount=self.cash//tmp
        buying_amount=rnd.randint(round(0.7*max_amount),max_amount)
        if(buying_amount>0):
            self.amount=self.amount+buying_amount
            self.cash=self.cash-tmp*buying_amount
            transaction=pd.DataFrame([["buy",i,tmp,buying_amount]],columns=["buy/sell","date","price","amount"])
            self.transactions= pd.concat([self.transactions,transaction],ignore_index=True)

# %% [markdown]
# `simplebolinger(original_prices,amount,startdate):`
#
#     Trade stocks by bollinger's strategy
#
#     Args:
#         original_prices:original prieces DataFrame
#         amount: Amount of stocks
#         startdate:Date of start of trading
#
#     Returns:
#         ans:Result of trading

# %%
def simplebolinger(original_prices,amount,startdate):
    prices=getbollinger(original_prices)
    prices=readydf(prices,startdate)
    drawbollinger(prices)
    ans=result_of_trading()
    start_capital=prices["adjusted_close"].iloc[0]*amount
    ans.amount=amount
    ans.cash=0
    for i in prices.index:
        if prices.loc[i,"adjusted_close"]>prices.loc[i,"adjusted_close_top"]:
            ans.sell(prices,i)
        if prices.loc[i,"adjusted_close"]<prices.loc[i,"adjusted_close_bottom"]:
            ans.buy(prices,i)
    end_capital=prices.iloc[-1:]["adjusted_close"][0]*ans.amount+ans.cash
    ans.profit=end_capital-start_capital
    ans.percentage_profit=100*ans.profit/start_capital
    return ans

# %% [markdown]
# `crossover(original_prices,amount,startdate):`
#
#     Trade stocks by crossover strategy
#
#     Args:
#         original_prices:original prieces DataFrame
#         amount: Amount of stocks
#         startdate:Date of start of trading
#
#     Returns:
#         ans:Result of trading struct

# %%
def crossover(original_prices,amount,startdate):
    prices=getcrossover(original_prices)
    prices=readydf(prices,startdate)
    drawcrossover(prices)
    ans=result_of_trading()
    start_capital=prices["adjusted_close"].iloc[0]*amount
    ans.amount=amount
    ans.cash=0
    for i in prices.index:
        if prices.loc[i,"Fast_close_rolling"]<prices.loc[i,"Slow_close_rolling"]:
            ans.sell(prices,i)
        if prices.loc[i,"Fast_close_rolling"]>prices.loc[i,"Slow_close_rolling"]:
            ans.buy(prices,i)
    end_capital=prices.iloc[-1:]["close"][0]*ans.amount+ans.cash
    ans.profit=end_capital-start_capital
    ans.percentage_profit=100*ans.profit/start_capital
    return ans

# %% [markdown]
# `read_poprtfolio_df(name):`
#
#     Load portfolio DataFrame from csv file
#
#     Args:
#         name: name of csv file with portfolio
#
#     Returns:
#         portfolio: portfolio DataFrame

# %%
def read_poprtfolio_df(name):
    portfolio=pd.read_csv(name+'.csv',names=['symbol','amount'])
    return(portfolio)

# %% [markdown]
# `loadprices(portfolio_names):`
#
#     Load list of DataFrames of prices of stocks of companies in portfolio_names DataFrame
#
#     Args:
#         portfolio_names: portfolio DataFrame
#
#     Returns:
#         prices_list:list of DataFrames of prices of stocks of companies in portfolio_names DataFrame

# %%
def loadprices(portfolio_names):
    prices_list=list()
    for i in portfolio.index:
        prices_list.append(prices_from_alphavantage_response(API_KEY,portfolio_names.loc[i]))
    return prices_list

# %% [markdown]
# `trade_portfolio(portfolio_amounts,prices_list,startdate,trade_func):`
#
#     Apply trade strategy for portfolio
#
#     Args:
#         portfolio_amounts: amounts of portfolio stocks
#         prices_list: list of prices DataFrames of every stock type
#         startdate: Date of start of trading
#         trade_func: trading strategy function
#
#     Returns:
#         results:list of results for every portfolio position

# %%
def trade_portfolio(portfolio_amounts,prices_list,startdate,trade_func):
    results=list()
    for i in range(len(prices_list)):
        results.append(trade_func(prices_list[i],portfolio_amounts.loc[i],startdate))
    return results

# %% [markdown]
# 'show_results(results):'
#
#     Print results of trading and summ of profits in $
#
#     Args:
#         results: list of result of trading
#
#     Returns:

# %%
def show_results(results):
    total_profit=0
    for i in results:
        print(i,'\n')
        total_profit=total_profit+i.profit
    print("Total profit =","%.2f" % total_profit,"$")

# %% [markdown]
# 'loadpair(name1,name2):'
#
#     Create struct for pair research $
#
#     Args:
#         name1: name of first stock
#         name2: name of second stock
#
#     Returns:
#         prices_pair: Struct of pair of stocks

# %%
def loadpair(name1,name2):
    prices_pair=list()
    prices_pair.append(prices_from_alphavantage_response(API_KEY,name1,"csv","TIME_SERIES_DAILY_ADJUSTED","full"))
    prices_pair.append(prices_from_alphavantage_response(API_KEY,name2,"csv","TIME_SERIES_DAILY_ADJUSTED","full"))
    prices_pair.append(name1)
    prices_pair.append(name2)
    return prices_pair

# %% [markdown]
# `research_pair(pair):`
#
#     Create struct for pair research
#
#     Args:
#         pair: Struct of pair of stocks
#
#     Returns:
#         Print results of pair research

# %%
def research_pair(pair):
    startdate=pair[0].index[0]
    if startdate<pair[1].index[0]:
        startdate=pair[1].index[0]
    pair[0]=readydf(pair[0],startdate)
    pair[1]=readydf(pair[1],startdate)
    fig,ax = plt.subplots(figsize=(12, 8))
    ax.set_title('Prices')
    ax.set_xlabel('Date')
    ax.plot(pair[0].index, pair[0]["adjusted_close"],label=pair[2], color="red")
    ax.plot(pair[1].index, pair[1]["adjusted_close"],label=pair[3], color="blue")
    ax.legend(loc='upper left', shadow=False, fontsize='x-large')
    pr1 = pd.Series(pair[0]["adjusted_close"],index=pair[0].index)
    pr2 = pd.Series(pair[1]["adjusted_close"],index=pair[1].index)
    total_corr=pr1.corr(pr2)
    print("Корреляция за всё время =","%.3f" % total_corr)

# %% [markdown]
# ## Демонстрация работы

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Загрузим портфель акций и зададим дату начала торгов

# %%
file_name="Portfolio"
startdate="2018-11-14"
portfolio=read_poprtfolio_df(file_name)
prices_list=loadprices(portfolio["symbol"])

# %%
portfolio
# Out:
#   symbol  amount
# 0   AAPL     100
# 1   MSFT     200

# %% [markdown]
# Нарисуем японские свечи для загруженных видов акций

# %%
for i in prices_list:
    drawcandlestick2(i)

# %% [markdown]
# ### Стратегия Боллинджера

# %% [markdown]
# Применим стратегию Боллинджера к каждой позиции из нашего портфеля

# %%
results_bollinger=trade_portfolio(portfolio["amount"],prices_list,startdate,simplebolinger)

# %% [markdown]
# Посмотрим насколько эффективной она оказалась для нашего портфеля акций

# %%
show_results(results_bollinger)
# Out:
# Profit=2779.51$
# Percentage profit=14.94%
# Amount=0
# Cash=21379.83$
#    buy/sell       date   price amount
# 0      sell 2018-11-28  180.94     84
# 1      sell 2018-12-03  184.82     15
# 2       buy 2018-12-07  168.49     96
# 3      sell 2018-12-13  170.95     75
# 4       buy 2018-12-14  165.48     73
# ..      ...        ...     ...    ...
# 24      buy 2019-03-06  174.52      4
# 25      buy 2019-03-07  172.50      1
# 26     sell 2019-03-11  178.90    108
# 27     sell 2019-03-14  183.73      9
# 28     sell 2019-03-15  186.12      2
#
# [29 rows x 4 columns]
#
#
# Profit=1165.72$
# Percentage profit=5.58%
# Amount=8
# Cash=21126.46$
#    buy/sell       date   price amount
# 0      sell 2018-11-26  106.47    191
# 1      sell 2018-11-28  111.12      7
# 2      sell 2018-12-03  112.09      1
# 3       buy 2018-12-04  108.52    144
# 4       buy 2018-12-07  104.82     39
# ..      ...        ...     ...    ...
# 22     sell 2019-03-11  112.83    166
# ...

# %% [markdown]
# ### Стратегия пересечения скользящих средних

# %% [markdown]
# Применим стратегию пересечения скользящих средних к каждой позиции из нашего портфеля

# %%
results_crossover=trade_portfolio(portfolio["amount"],prices_list,startdate,crossover)

# %% [markdown]
# Посмотрим насколько эффективной она оказалась для нашего портфеля акций

# %%
show_results(results_crossover)
# Out:
# Profit=3540.29$
# Percentage profit=21.41%
# Amount=105
# Cash=131.70$
#   buy/sell       date   price amount
# 0     sell 2018-12-18  166.07     91
# 1     sell 2018-12-19  160.89      8
# 2     sell 2018-12-20  156.83      1
# 3      buy 2019-01-28  156.30     87
# 4      buy 2019-01-29  154.68     14
# 5      buy 2019-01-30  165.25      4
#
#
# Profit=2561.06$
# Percentage profit=12.37%
# Amount=197
# Cash=32.00$
#   buy/sell       date   price amount
# 0     sell 2018-12-18  103.97    195
# 1     sell 2018-12-19  103.69      5
# 2      buy 2019-01-16  105.38    196
# 3      buy 2019-01-17  106.12      1
#
#
# Total profit = 6101.35 $

# %% [markdown]
# ## Пары компаний

# %% [markdown]
# ### Koninklijke Philips NV и LGC Capital Ltd

# %% [markdown]
# <p style="text-align:justify">Компания <strong>Koninklijke Philips N.V.</strong> (англ. Royal Philips) появилась в 1891 году как небольшая фабрика по производству электрических ламп. Теперь это международный концерн, деятельность которого делится на три направления:<br>
# •  здравоохранение<br>
# •  световые решения<br>
# •  потребительские товары<br>
# В 2012 году Philips и один из крупнейших мировых производителей компьютерных мониторов и ЖК-телевизоров TPV Technology (бренд AOC) создали совместное предприятие под названием TP Vision. Доли были распределены так: 70% новой компании получила гонконгская TPV Technology, а 30% — концерн Royal Philips. Именно TP Vision сегодня занимается производством телевизоров под брендом Philips.<br>
# Согласно отчетам за 2018 год прибыль компании возросла в несколько раз. Поэтому аналитики прогнозируют что в 2019 году цены на акции компании возрастут.<br>
# Но фондовые ринки Нидерландов дают понять, что не все так гладко.<br>
# «Фондовый рынок Нидерландов завершил торги пятницы ростом за счет укрепления секторов телекоммуникаций»
# Лидерами падения стали акции Koninklijke Philips NV (AS:PHG), цена которых упала на 0,56 п. (1,62%), завершив сессию на отметке 33,80. Акции ASR Nederland NV (AS:ASRNL) поднялись на 0,50 п. (1,36%), закрывшись на уровне 36,36, а ABN AMRO Group NV (AS:ABNd) снизились в цене на 0,27 п. (1,24%) и завершили торги на отметке 21,45.</p>

# %%
my_pair1=loadpair("PHG","LPL")

# %%
research_pair(my_pair1)
# Out:
# Корреляция за всё время = -0.031

# %% [markdown]
# ### Вывод
# <p style="text-align:justify">Philips и LG.
# Согласно отчетам за 2018 год прибыль компании Philips возросла в несколько раз. Другая ситуация у компании LG, где произошло рекордное падение акций.
# ‘По итогам второго квартала LG Electronics сообщила о более чем 36-процентном падении чистой прибыли, а также в очередной раз зарегистрировала убытки в мобильном бизнесе. Еще одним убыточным направлением LG был бизнес по выпуску автомобильных компонентов.’
#  Поэтому аналитики прогнозируют что в 2019 году цены на акции компании Philips возрастут. Чего не скажеш про ситуацию в компании LG.
# Подробнее мы изобразили на графиках, где можно наглядно просмотреть последние изменения в ценах на акции компаний.</p>

# %% [markdown]
# ### Tesla и ExxonMobil

# %% [markdown]
# C развитием электрокаров цены на классические энергоресуры и акции компаний, которые ими торгуют должны падать.

# %%
my_pair2=loadpair("TSLA","XOM")

# %%
research_pair(my_pair2)
# Out:
# Корреляция за всё время = 0.643

# %% [markdown]
# ### Вывод
# Заметить это не удалось.
