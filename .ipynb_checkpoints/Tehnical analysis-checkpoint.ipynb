# %%
import requests
import json
import time
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_finance import candlestick2_ohlc
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib.dates import date2num, DayLocator, DateFormatter
pd.options.display.max_rows = 10
# %config InlineBackend.figure_format = 'svg'
API_KEY = "MQ6BIXLQCTZ9I3DV"

# %%
def prices_from_json_response(apikey,symbol,function,outputsize):#dataframe цен вида акций из json из api alphavanttage
    API_URL = "https://www.alphavantage.co/query"
    data = {
        "function": function,
        "symbol": symbol,
        "outputsize": outputsize,
        "datatype": "JSON",
        "apikey": apikey
        }
    json_data=requests.get(API_URL, data).json()['Time Series (Daily)']
    prices=pd.DataFrame(json_data).transpose()
    prices.index.names = ['Date']
    prices.index=pd.to_datetime(prices.index, format='%Y-%m-%d')
    if function=='TIME_SERIES_DAILY':
        prices=prices.rename(columns={"1. open" : "open", "2. high":"high", "3. low":"low", "4. close":"close", "5. volume":"volume"})
    if function=='TIME_SERIES_DAILY_ADJUSTED':
        prices=prices.rename(columns={"1. open" : "open", "2. high":"high", "3. low":"low", "4. close":"close", "5. adjusted close":"adjusted close","6. volume":"volume","7. dividend amount":"dividend amount","8. split coefficient":"split coefficient"})
    prices=prices.astype(float)
    prices = prices.sort_index(axis=0 ,ascending=True)
    return prices

# %%
def prices_from_csv_response(apikey,symbol,function,outputsize):#dataframe цен вида акций из scv из api alphavanttage
    base_url = 'https://www.alphavantage.co/query?'
    request_url = base_url + '&'.join\
        (['function=' + function,
          'outputsize=' + outputsize,
          'datatype=' + 'csv',
          'symbol=' + symbol,
          'apikey=' + apikey])
    data = pd.read_csv(request_url, index_col='timestamp', parse_dates=True)    
    data=data.iloc[::-1]
    data.index.names = ['Date']
    return data

# %%
def prices_from_alphavantage_response(#dataframe цен вида акций из api alphavanttage
        apikey, symbol,datatype,
        function='TIME_SERIES_DAILY_ADJUSTED',
        outputsize='compact'):
        if datatype=="JSON" or datatype=="json":
            return prices_from_json_response(apikey,symbol,function,outputsize)
        elif datatype=="CSV" or datatype=="csv":
            return prices_from_csv_response(apikey,symbol,function,outputsize)
        else:
            print("Not supported format")

# %%
def read_prices_df_from_csv(name):#читает df цен из файла
    return(pd.read_csv(name+'.csv',index_col='Date'))

# %%
def readydf(df,startdate):#отсекает часть данных от начала файлы до даты startdate
    ansdf=df.copy()
    return ansdf[ansdf.index>=startdate]

# %%
def getbollinger(prices,window):#создаёт dataframe для стратегий Боллинжера
    bollingerprices=prices.copy()
    bollingerprices["close rolling"]=prices["close"].rolling(window).mean()
    tmp=prices["close"].rolling(window).std()
    bollingerprices["close top"]=bollingerprices["close rolling"]+tmp
    bollingerprices["close bottom"]=bollingerprices["close rolling"]-tmp
    #first_date=bollingerprices.first_valid_index()
    #first_clean_date=first_date+pd.DateOffset(days=window)
    return bollingerprices.iloc[window:]

# %%
def drawcandlestick(df):#рисует японские свечки из dataframe цен вида акций
    fig, ax = plt.subplots(figsize=(7, 7))
    candlestick2_ohlc(ax,df['open'],df['high'],df['low'],df['close'],width=0.5) 
    ax.xaxis.set_major_locator(ticker.MaxNLocator(10))
    xdate = df.index.date
    def mydate(x,pos):
        try:
            return xdate[int(x)]
        except IndexError:
            return ''
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(mydate))
    fig.autofmt_xdate()
    fig.tight_layout()
    plt.show()
    return

# %%
def drawbollinger(bollingerprices):#рисует график цен, скользящее среднее и линии Боллинжера
    drawcandlestick(bollingerprices)
    color='#0066FF'
    fig,ax = plt.subplots(figsize=(8, 8))
    ax.set_title('Price and Bollinger Bands')
    ax.set_xlabel('Date')
    ax.set_ylabel('SMA and Bollinger Bands')
    ax.plot(bollingerprices.index, bollingerprices["close rolling"], color=color)
    ax.fill_between(
            bollingerprices.index,  
            bollingerprices["close bottom"],
            bollingerprices["close top"],
            color=color, alpha=0.1)
    ax.plot(
            bollingerprices.index,  
            bollingerprices["close bottom"],
            bollingerprices["close top"],
            color=color, linewidth=1, alpha=0.4)
    #ax.plot(bollingerprices.index, bollingerprices["close"],
            #color=color, linewidth=1, alpha=0.4)
    ax.xaxis.set_major_locator(ticker.MaxNLocator(10))
    myFmt = mdates.DateFormatter('%Y-%m-%d')
    ax.xaxis.set_major_formatter(myFmt)
    fig.autofmt_xdate()
    #fig.tight_layout()
    return

# %%
class result_of_trading:
    income=0
    transactions = pd.DataFrame(columns=["buy/sell","date","price"])

# %%
def simplebolinger(prices,ammount):#реализация простейшей стратегии Боллинжера
    start_capital=prices["close"].iloc[0]*ammount
    cash=0
    ans=result_of_trading()
    for i in prices.index:
        if ammount>0 and prices.loc[i,"close"]>prices.loc[i,"close top"]:
            tmp=prices.loc[i,"close"]
            cash=cash+tmp*ammount
            ammount=0
            transaction=pd.DataFrame([["sell",i,tmp]],columns=["buy/sell","date","price"])
            ans.transactions= pd.concat([ans.transactions,transaction],ignore_index=True)
        if ammount==0 and prices.loc[i,"close"]<prices.loc[i,"close bottom"]:
            tmp=prices.loc[i,"close"]
            ammount=cash//tmp
            cash=cash%tmp
            transaction=pd.DataFrame([["buy",i,tmp]],columns=["buy/sell","date","price"])
            ans.transactions= pd.concat([ans.transactions,transaction],ignore_index=True)
    end_capital=prices.iloc[-1:]["close"]*ammount+cash
    ans.income=end_capital-start_capital
    return ans

# %%
def read_poprtfolio_df(name):#cчитывает портфель из файла
    return(pd.read_csv(name+'.csv',names=['symbol','amount']))

# %%
read_poprtfolio_df("Portfolio")
# Out:
#   symbol  amount
# 0   AAPL     100
# 1   NSFT     200

# %%
#def portfolio(path,Type,startdate,id_func):#функция, которая выполняет стратегию для массива акций и возвращает массив result_of_trading
    #считать дф с портфелем из сsv фаила
    #cоздать массив dfов цен из API.
    #apply.getbollinger()
    #apply.readydf(startdate)
    #cоздать и вернуть массив result_of_trading для функции с id=id_func

# %%
#TO DO

#функция которая рисует цены графиков 2х и считает кореляцию
#(матрица корреляции
#гистограммы корреляция)

#свечки — объём продаж
#добавить в стратегии элемент случайности(не перманентная продажа)

#стратегия кросовер(пересечение скользящих средних)
#желательное окно/настоящее окно
#оформить стратегии в псевдокласс с одним public методом trigger(id),
#который вызывает функцию в зависимости от id
#добавить стратегий

#комментарии(документация в markdown для каждой функции)
#plotly

# %%
prices=prices_from_alphavantage_response(API_KEY,"INTC","csv")

# %%
prices=getbollinger(prices,20)
startdate="2018-11-14"#дата начала торгов(гипотетическая)
prices=readydf(prices,startdate)
drawbollinger(prices)

# %%
a=simplebolinger(prices,500)
print(a.income)
print(a.transactions)
# Out:
# Date
# 2019-03-22    3100.16
# Name: close, dtype: float64
#   buy/sell       date  price
# 0     sell 2018-11-28  48.86
# 1      buy 2018-12-07  46.24
# 2     sell 2019-01-09  48.01
# 3      buy 2019-01-29  46.54
# 4     sell 2019-02-04  49.22
